# %%
'''
The success of a shopping center can be represented as a function
of the distance (in km) from the center of the population and the
number of clients (in hundreds of people) who will visit the centre
each day. A set of collected data is given in the table below:
'''
import numpy as np
import pandas as pd
import matplotlib.pyplot as mplt
# %matplotlib inline
import statsmodels.api as sm
import seaborn as sns


No_of_Customers=[5,8,11,12,13,14,15,16,17]
distance=[12,8,7,8,4,3,2,1,0.5]
data_frame= pd.DataFrame.from_dict(dict([('No_of_Customers',No_of_Customers),('distance',distance)]))
data_frame
# Out:
#    No_of_Customers  distance
# 0                5      12.0
# 1                8       8.0
# 2               11       7.0
# 3               12       8.0
# 4               13       4.0
# 5               14       3.0
# 6               15       2.0
# 7               16       1.0
# 8               17       0.5

# %%
#a) Scatter plot
y1=data_frame['No_of_Customers']
y1
mplt.ylabel('No_of_Customers',fontsize=15)
x1=data_frame['distance']
mplt.xlabel('distance',fontsize=15)
mplt.scatter(x1,y1)

# %%
#Box plot
sns.boxplot(x='No_of_Customers',y='distance',data=data_frame,hue='No_of_Customers')
# Out:
# <AxesSubplot:xlabel='No_of_Customers', ylabel='distance'>

# %%
#Density plot
sns.distplot(data_frame['distance'])
# Out:
# C:\Users\adak0\AppData\Local\Programs\Python\Python38-32\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='distance', ylabel='Density'>

# %%
x=data_frame['No_of_Customers']
y1=data_frame['distance']
y=sm.add_constant(y1)
result=sm.OLS(x,y).fit()
result.summary()
# Out:
# C:\Users\adak0\AppData\Local\Programs\Python\Python38-32\lib\site-packages\scipy\stats\stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=9
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        No_of_Customers   R-squared:                       0.920
# Model:                            OLS   Adj. R-squared:                  0.908
# Method:                 Least Squares   F-statistic:                     80.19
# Date:                Tue, 11 May 2021   Prob (F-statistic):           4.41e-05
# Time:                        18:54:25   Log-Likelihood:                -13.077
# No. Observations:                   9   AIC:                             30.15
# Df Residuals:                       7   BIC:                             30.55
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
yhat=-0.9542*y1+(17.1572)
yhat
# Out:
# 0     5.7068
# 1     9.5236
# 2    10.4778
# 3     9.5236
# 4    13.3404
# 5    14.2946
# 6    15.2488
# 7    16.2030
# 8    16.6801
# Name: distance, dtype: float64

# %%
'''(a) Calculate the linear correlation coefficient.'''
data_frame.No_of_Customers.corr(data_frame.distance)
# Out:
# -0.9590173769861744

# %%
'''(b) If the mall is located 3 miles away from the center of the
population, how many customers should the shopping center
expect
'''
no_of_customer_3_miles=-0.9542*3+(17.1572)
print('no_of_customer_3_miles: ',no_of_customer_3_miles)
# Out:
# no_of_customer_3_miles:  14.294599999999999

# %%
y=data_frame['distance']
x1=data_frame['No_of_Customers']
x=sm.add_constant(x1)
result=sm.OLS(y,x).fit()
result.summary()
# Out:
# C:\Users\adak0\AppData\Local\Programs\Python\Python38-32\lib\site-packages\scipy\stats\stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=9
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               distance   R-squared:                       0.920
# Model:                            OLS   Adj. R-squared:                  0.908
# Method:                 Least Squares   F-statistic:                     80.19
# Date:                Tue, 11 May 2021   Prob (F-statistic):           4.41e-05
# Time:                        19:03:03   Log-Likelihood:                -13.123
# No. Observations:                   9   AIC:                             30.25
# Df Residuals:                       7   BIC:                             30.64
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
yhat=-0.9542*x1+(16.9435)
yhat
# Out:
# 0    12.1725
# 1     9.3099
# 2     6.4473
# 3     5.4931
# 4     4.5389
# 5     3.5847
# 6     2.6305
# 7     1.6763
# 8     0.7221
# Name: No_of_Customers, dtype: float64

# %%
'''
(c) To receive 900 customers a day, at what distance from the
center of the population should the shopping centre be located?
'''
recieve_900_customer_a_day=-0.9542*900+(16.9435)
print('recieve_900_customer_a_day: ',recieve_900_customer_a_day)
# Out:
# recieve_900_customer_a_day:  -841.8365000000001
