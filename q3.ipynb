# %%
import math
import matplotlib.pyplot as  mplot
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
no_of_sleep_hrs=[6,7,8,9,10]
no_of_hrs_smart_phone_use=[18,16,14,12,7]
data=pd.DataFrame.from_dict(dict([('no_of_sleep_hrs',no_of_sleep_hrs),('no_of_hrs_smart_phone_use',no_of_hrs_smart_phone_use)]))
print(data.describe())
# Out:
#        no_of_sleep_hrs  no_of_hrs_smart_phone_use
# count         5.000000                   5.000000
# mean          8.000000                  13.400000
# std           1.581139                   4.219005
# min           6.000000                   7.000000
# 25%           7.000000                  12.000000
# 50%           8.000000                  14.000000
# 75%           9.000000                  16.000000
# max          10.000000                  18.000000

# %%
#Scatter plot
#y->dependent variable
#x->independent variable
y1=data['no_of_hrs_smart_phone_use']
mplot.ylabel('hrs smart phone use',fontsize=15)
x1=data['no_of_sleep_hrs']
mplot.xlabel('hrs of sleep',fontsize=15)
mplot.scatter(x1,y1)

# %%
#Box plot
sns.boxplot(x='no_of_sleep_hrs',y='no_of_hrs_smart_phone_use',data=data,hue='no_of_sleep_hrs', linewidth=2.5)
# Out:
# <AxesSubplot:xlabel='no_of_sleep_hrs', ylabel='no_of_hrs_smart_phone_use'>

# %%
sns.distplot(data['no_of_sleep_hrs'])
# Out:
# C:\Users\adak0\AppData\Local\Programs\Python\Python38-32\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='no_of_sleep_hrs', ylabel='Density'>

# %%
x=sm.add_constant(x1)
result=sm.OLS(y,x).fit()
result.summary()
# Out:
# C:\Users\adak0\AppData\Local\Programs\Python\Python38-32\lib\site-packages\statsmodels\stats\stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# ...
# Dep. Variable:     no_of_hrs_smart_phone_use   R-squared:                       0.949
# Model:                                   OLS   Adj. R-squared:                  0.933
# Method:                        Least Squares   F-statistic:                     56.33
# Date:                       Fri, 14 May 2021   Prob (F-statistic):            0.00490
# Time:                               02:26:30   Log-Likelihood:                -6.2734
# No. Observations:                          5   AIC:                             16.55
# ...

# %%
#(a)Calculate the correlation coefficient
data.no_of_sleep_hrs.corr(data.no_of_hrs_smart_phone_use)
# Out:
# -0.97439119569462

# %%
#(b) Determine the equation of the regression line of y on x.
mplot.ylabel('hrs smart phone use',fontsize=15)
mplot.xlabel('hrs of sleep',fontsize=15)
mplot.scatter(x1,y)
y_hat=-2.6000*x1+34.2000
fig=mplot.plot(x1,y_hat,lw=2,c="red",label="regression line")
